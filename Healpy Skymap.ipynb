# %%
import numpy as np
import healpy as hp
# %matplotlib inline

# %%
Nside = 2**6              # Specify nside parameter
Npix = 12 * Nside**2      # Number of pixels
pix_sr = (4*np.pi)/Npix   # Pixel size  [sr]

# Coordinate corresponding to each pixel index
theta, phi = hp.pixelfunc.pix2ang(Nside,np.arange(Npix))

# %%
# Create random poisson sky-map
poisson_map = np.random.poisson(10,Npix)

hp.mollview(poisson_map, title='', unit='')
hp.graticule()
# Out:
# 0.0 180.0 -180.0 180.0
# The interval between parallels is 30 deg -0.00'.
# The interval between meridians is 30 deg -0.00'.

# %%
from functions import *

# %%
D_map = D_factors_for_healpix(Nside)
lon, lat = hp.pixelfunc.pix2ang(Nside, np.arange(Npix), lonlat=True)

# Specify Galactic plane region to mask
lat_max = 10
D_map_masked = np.where((lat<lat_max) & (lat>-lat_max),hp.UNSEEN,D_map)

hp.mollview(D_map_masked, title='', unit='log[D/GeV/cm^2]')
hp.graticule()

# %%
from functions import *

# %%
D_map = D_factors_for_healpix(Nside)
lon, lat = hp.pixelfunc.pix2ang(Nside, np.arange(Npix), lonlat=True)

# Specify Galactic plane region to mask
lat_max = 10
D_map_masked = np.where((lat<lat_max) & (lat>-lat_max),hp.UNSEEN,D_map)

hp.mollview(D_map_masked, title='', unit='log[D/GeV/cm^2]')
hp.graticule()
# Out:
# 0.0 180.0 -180.0 180.0
# The interval between parallels is 30 deg -0.00'.
# The interval between meridians is 30 deg -0.00'.
