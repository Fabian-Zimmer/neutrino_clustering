# %%
# %load_ext autoreload
# %autoreload 2

# Here we import functions I compiled over the years
from Shared.shared import *
from Shared.specific_CNB_sim import *

# Here we import the functions from your specific file (empty for now)
from Shared.specific_CNB_OK import *

# For now I made a folder in the figures_local folder and in the sim_output folder names "OK_sim", where all the figures and files will be, respectively
sim_name = f"OK_sim"
sim_folder = f"sim_output/{sim_name}"
fig_folder = f"figures_local/{sim_name}"

# These are some mass ranges we need for analyzing simulation data
nu_m_range = jnp.load(f"{sim_folder}/neutrino_massrange_eV.npy")
nu_m_picks = jnp.array([0.01, 0.05, 0.1, 0.2, 0.3])*Params.eV

# This is a class instantiation that carries some simulation parameters
simdata = SimData(sim_folder)
